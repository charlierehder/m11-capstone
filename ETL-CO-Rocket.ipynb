# %%
###### Mount Point 1 through Oauth security.
storageAccount = "gen10datafund2202"
storageContainer = "team-rocket"
clientSecret = "B4g8Q~1VyZJa5WszLHwdEQNq4YIaHmT4DevRBcwI"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/alysia/COetl"
#outcomes.csv


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/alysia/COetl has been unmounted.
# Out[1]: True</div>

# %%
# view container blobs 
# csv from Kafka stream
display(dbutils.fs.ls("/mnt/alysia/COetl"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#read in file
df = spark.read.options(header='True').csv('/mnt/alysia/COetl/outcomes.csv')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# print column names
print(df.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
# dropping unnecessary columns as documented in Exercise-Initial-Capstone-Data-Sources
# viewing dataframe to make sure correct columns are dropped

df = df.select('facility_id', 'state', 'mort30ami_baseline_rate', 'mort30ami_performance_rate', 'mort30hf_baseline_rate', 'mort30hf_performance_rate', 'mort30pn_baseline_rate', 'mort30pn_performance_rate', 'comphipknee_baseline_rate', 'comphipknee_performance_rate')
df.show()
display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+-----------------------+--------------------------+----------------------+-------------------------+----------------------+-------------------------+-------------------------+----------------------------+
# facility_id|state|mort30ami_baseline_rate|mort30ami_performance_rate|mort30hf_baseline_rate|mort30hf_performance_rate|mort30pn_baseline_rate|mort30pn_performance_rate|comphipknee_baseline_rate|comphipknee_performance_rate|
# ...

# %%
print(df.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;facility_id&#39;, &#39;state&#39;, &#39;mort30ami_baseline_rate&#39;, &#39;mort30ami_performance_rate&#39;, &#39;mort30hf_baseline_rate&#39;, &#39;mort30hf_performance_rate&#39;, &#39;mort30pn_baseline_rate&#39;, &#39;mort30pn_performance_rate&#39;, &#39;comphipknee_baseline_rate&#39;, &#39;comphipknee_performance_rate&#39;]
# </div>

# %%
# renaming columns for SQL database/readability
# confirming dataframe accepted column name changes

df = df.withColumnRenamed("facility_id","Facility_ID").withColumnRenamed("mort30ami_baseline_rate","MORT_AMI_Baseline").withColumnRenamed("mort30ami_performance_rate","MORT_AMI_Perform").withColumnRenamed("mort30hf_baseline_rate","MORT_HF_Baseline").withColumnRenamed("mort30hf_performance_rate","MORT_HF_Perform").withColumnRenamed("mort30pn_baseline_rate","MORT_PN_Baseline").withColumnRenamed("mort30pn_performance_rate","MORT_PN_Perform").withColumnRenamed("comphipknee_baseline_rate","COMP_HIP_KNEE_Baseline").withColumnRenamed("comphipknee_performance_rate","COMP_HIP_KNEE_Perform")
df.show()
display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+
# Facility_ID|state|MORT_AMI_Baseline|MORT_AMI_Perform|MORT_HF_Baseline|MORT_HF_Perform|MORT_PN_Baseline|MORT_PN_Perform|COMP_HIP_KNEE_Baseline|COMP_HIP_KNEE_Perform|
# +-----------+-----+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+
# ...

# %%
# view current data types
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Facility_ID: string (nullable = true)
# -- state: string (nullable = true)
# -- MORT_AMI_Baseline: string (nullable = true)
# -- MORT_AMI_Perform: string (nullable = true)
# -- MORT_HF_Baseline: string (nullable = true)
# -- MORT_HF_Perform: string (nullable = true)
# -- MORT_PN_Baseline: string (nullable = true)
# -- MORT_PN_Perform: string (nullable = true)
# -- COMP_HIP_KNEE_Baseline: string (nullable = true)
# -- COMP_HIP_KNEE_Perform: string (nullable = true)
#
# </div>

# %%
# change data types for appropriate columns
# int: facility id, zip code
# double: all baseline and performance score columns
# display dataframe and print schema to confirm changes accepted
df = df.withColumn('MORT_AMI_Baseline', df.MORT_AMI_Baseline.cast('double')).withColumn('MORT_AMI_Perform', df.MORT_AMI_Perform.cast('double')).withColumn('MORT_HF_Baseline', df.MORT_HF_Baseline.cast('double')).withColumn('MORT_HF_Perform', df.MORT_HF_Perform.cast('double')).withColumn('MORT_PN_Baseline', df.MORT_PN_Baseline.cast('double')).withColumn('MORT_PN_Perform', df.MORT_PN_Perform.cast('double')).withColumn('COMP_HIP_KNEE_Baseline', df.COMP_HIP_KNEE_Baseline.cast('double')).withColumn('COMP_HIP_KNEE_Perform', df.COMP_HIP_KNEE_Perform.cast('double'))
df.show()
display(df)
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+
# Facility_ID|state|MORT_AMI_Baseline|MORT_AMI_Perform|MORT_HF_Baseline|MORT_HF_Perform|MORT_PN_Baseline|MORT_PN_Perform|COMP_HIP_KNEE_Baseline|COMP_HIP_KNEE_Perform|
# +-----------+-----+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+
# ...

# %%
# dealing with missing values/nulls by imputing the median value of the respective column
from pyspark.sql.functions import col

# filter numeric cols
num_cols = [col_type[0] for col_type in filter(lambda dtype: dtype[1] in {"bigint", "double", "int"}, df.dtypes)]
# compute a dict with <col_name, median_value>
median_dict = dict()
for c in num_cols:
   median_dict[c] = df.stat.approxQuantile(c, [0.5], 0.001)[0]
df_imputed = df.na.fill(median_dict)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# view finalized data frame
display(df_imputed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# drop columns for SQL 
df_imputed1 = df_imputed.drop('State')
df_imputed1.show()
display(df_imputed1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+
# Facility_ID|MORT_AMI_Baseline|MORT_AMI_Perform|MORT_HF_Baseline|MORT_HF_Perform|MORT_PN_Baseline|MORT_PN_Perform|COMP_HIP_KNEE_Baseline|COMP_HIP_KNEE_Perform|
# +-----------+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+
# ...

# %%
display(df_imputed1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# add ClinicalOutcome_ID for SQL DB
from pyspark.sql.window import Window as W
from pyspark.sql import functions as F
df = df_imputed1.withColumn("ClinicalOutcome_ID", F.monotonically_increasing_id())

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# correct order of ClinicalOutcome_ID
from pyspark.sql.window import Window as W
from pyspark.sql import functions as F

windowSpec = W.orderBy("Facility_ID")
df_imputed1 = df.withColumn("ClinicalOutcome_ID", F.row_number().over(windowSpec))
df_imputed1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+------------------+
# Facility_ID|MORT_AMI_Baseline|MORT_AMI_Perform|MORT_HF_Baseline|MORT_HF_Perform|MORT_PN_Baseline|MORT_PN_Perform|COMP_HIP_KNEE_Baseline|COMP_HIP_KNEE_Perform|ClinicalOutcome_ID|
# +-----------+-----------------+----------------+----------------+---------------+----------------+---------------+----------------------+---------------------+------------------+
# ...

# %%
# confirm changes
display(df_imputed1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# establish connection to COPY database
database = "Copy_teamRocket"
table = "dbo.ClinicalOutcomeScores"
user = "gen10dbadmin"
password  = "vbtwrEmgSG12mabBr9ReZkcPrrDbTR-Y"
server = "gen10-data-fundamentals-22-02-sql-server.database.windows.net"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# write ClinicalOutcomeScores table to database
df_imputed1.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .mode("overwrite") \
    .option("dbtable", table) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # establish connection to database
# database = "teamRocket"
# table = "dbo.ClinicalOutcomeScores"
# user = "rocketIO"
# password  = "Me0wt#1313"
# server = "gen10-data-fundamentals-22-02-sql-server.database.windows.net"
# url = "jdbc:sqlserver://{server}:1433;databaseName={database};user={user};password={password}"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# # write ClinicalOutcomeScores table to database
# df_imputed1.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
#     .mode("append") \
#     .option("dbtable", table) \
#     .option("user", user) \
#     .option("password", password) \
#     .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
#     .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
